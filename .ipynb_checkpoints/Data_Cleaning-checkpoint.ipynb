# %%
import pandas as pd
data = pd.read_excel('Surfacewq.xlsx')

# %%
data.head()
data.tail()
# Out:
#        Amount of Calcium (Ca)  Amount of Magnesium (Mg)  \
# 13029                   20.84                      3.88
# 13030                   27.25                      7.78
# 13031                   32.80                      8.40
# 13032                   30.41                     12.64
# 13033                   35.69                      8.38
#
#        Amount of Sodium (Na)  Amount of Potassium (K)  \
# 13029                   14.8                      2.8
# 13030                   11.5                      2.3
# 13031                   14.8                      2.1
# 13032                   11.0                      2.6
# 13033                   41.3                      9.2
#
#        Total Amount (N+K) (mg/L)  Ca Weight (%) (meq/L)  \
# 13029                       17.6               1.039972
# 13030                       13.8               1.359848
# 13031                       16.9               1.636808
# 13032                       13.6               1.517541
# ...

# %%
for col in data.columns:
    print(col)
# Out:
# Amount of Calcium (Ca)
# Amount of Magnesium (Mg)
# Amount of Sodium (Na)
# Amount of Potassium (K)
# Total Amount (N+K) (mg/L)
# Ca Weight (%) (meq/L)
# Mg Weight (%) (meq/L)
# Na Weight (%) (meq/L)
# K Weight (%) (meq/L)
# Total Amount (Na+K %) (meq/L)
# Total Weight Amount (Ca + Mg+ Na+K %) (meq/L)
# Ca Relative Conc (meq%)
# Mg Relative Conc (meq%)
# Na+K Relative Conc (meq%)
# Amount of Chloride (Cl)
# Amount of Sulfate (SO4)
# Amount of Carbonate (CO3)
# Amount of Hydrogencarbonate (HCO3)
# Cl Weight (%) (meq/L)
# SO4 Weight (%) (meq/L)
# CO3 Weight (%) (meq/L)
# HCO3 Weight (%) (meq/L)
# Total Amount (CO3+HCO3 %) (meq/L)
# Total Weight Amount (Cl + SO4+ CO3+HCO3 %) (meq/L)
# Cl Relative Conc (meq%)
# SO4 Relative Conc (meq%)
# CO3 + HCO3 Relative Conc (meq%)
# ROWID
# District LGD Code
# Amount of Total Dissolved Solids (TDS)
# Amount of Potential of Hydrogen (H+, pH)
# Country
# State LGD Code
# State
# District
# Year
# Surface Water Station
# Surface Water Station Latitude
# ...

# %%
data.isnull()
# Out:
#        Amount of Calcium (Ca)  Amount of Magnesium (Mg)  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
# ...                       ...                       ...
# 13029                   False                     False
# 13030                   False                     False
# 13031                   False                     False
# 13032                   False                     False
# 13033                   False                     False
#
#        Amount of Sodium (Na)  Amount of Potassium (K)  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# ...

# %%
sorted = data.sort_values(by='Year')
sorted.tail()
# Out:
#        Amount of Calcium (Ca)  Amount of Magnesium (Mg)  \
# 6034                    74.44                     51.40
# 12033                   13.36                      4.36
# 12032                   23.04                      3.45
# 6673                    57.60                     13.00
# 4513                    49.30                     12.80
#
#        Amount of Sodium (Na)  Amount of Potassium (K)  \
# 6034                     NaN                      NaN
# 12033                  15.50                     1.30
# 12032                   2.09                     1.46
# 6673                   45.55                     2.90
# 4513                   24.54                     1.70
#
#        Total Amount (N+K) (mg/L)  Ca Weight (%) (meq/L)  \
# 6034                        0.00               3.714756
# 12033                      16.80               0.666700
# 12032                       3.55               1.149758
# 6673                       48.45               2.874395
# ...

# %%
uttar = data.loc[(data['Year'] >= 2011) & (data['State'] == 'Uttar Pradesh')]
uttar.head()
# Out:
#       Amount of Calcium (Ca)  Amount of Magnesium (Mg)  Amount of Sodium (Na)  \
# 8038                   67.80                  33.93900                38.0995
# 8039                   62.36                  29.67000                93.0000
# 8040                   63.40                  39.97350               169.0500
# 8041                   58.70                  25.08975               131.9050
# 8042                   46.00                  38.90000               144.0000
#
#       Amount of Potassium (K)  Total Amount (N+K) (mg/L)  \
# 8038                 0.830875                  38.930375
# 8039                10.200000                 103.200000
# 8040                12.121000                 181.171000
# 8041                18.377000                 150.282000
# 8042                18.800000                 162.800000
#
#       Ca Weight (%) (meq/L)  Mg Weight (%) (meq/L)  Na Weight (%) (meq/L)  \
# 8038               3.383402               2.792759               1.657221
# ...

# %%
india2012 = data.loc[(data['Year'] == 2012)]
# Out:
#        Amount of Calcium (Ca)  Amount of Magnesium (Mg)  \
# 13010                   40.08                     17.50
# 13016                   35.26                      2.91
# 13022                   25.65                      4.86
# 13026                   22.44                      6.80
# 13030                   27.25                      7.78
#
#        Amount of Sodium (Na)  Amount of Potassium (K)  \
# 13010                    2.7                      1.0
# 13016                   86.0                      4.3
# 13022                   16.6                      3.5
# 13026                   11.4                      2.1
# 13030                   11.5                      2.3
#
#        Total Amount (N+K) (mg/L)  Ca Weight (%) (meq/L)  \
# 13010                        3.7               2.000100
# 13016                       90.3               1.759569
# 13022                       20.1               1.280004
# 13026                       13.5               1.119816
# ...

# %%
# Out:
#       Amount of Calcium (Ca)  Amount of Magnesium (Mg)  Amount of Sodium (Na)  \
# 3802                   35.43                     14.35                   40.0
# 3810                   38.79                     68.71                   96.0
# 3818                   31.09                     62.27                   92.0
# 3826                   31.74                     16.93                   23.0
# 3834                   31.10                     18.54                   22.0
#
#       Amount of Potassium (K)  Total Amount (N+K) (mg/L)  \
# 3802                     15.0                       55.0
# 3810                    214.0                      310.0
# 3818                      7.0                       99.0
# 3826                      8.0                       31.0
# 3834                      8.0                       30.0
#
#       Ca Weight (%) (meq/L)  Mg Weight (%) (meq/L)  Na Weight (%) (meq/L)  \
# 3802               1.768052               1.180827               1.739887
# ...

# %%
#reading multiple sheets from a single excel file
data2 = pd.ExcelFile('data2.xlsx')
uttar_sw=pd.read_excel(data2,'UttarPradesh_SurfaceWQ')
andhra_sw = pd.read_excel(data2, 'Andhra Pradesh_SurfaceWQ')
madhya_sw = pd.read_excel(data2, 'MadhyaPradesh_WQ')

# %%
andhra_sw.tail()
# Out:
#      Amount of Calcium (Ca)  Amount of Magnesium (Mg)  Amount of Sodium (Na)  \
# 311                   28.69                     14.34                  106.5
# 312                   31.40                     16.19                  113.0
# 313                   20.04                      5.06                   46.6
# 314                   35.07                     15.19                  120.0
# 315                   13.36                      5.06                   40.1
#
#      Amount of Potassium (K)  Total Amount (N+K) (mg/L)  \
# 311                      6.6                      113.1
# 312                      4.1                      117.1
# 313                      3.4                       50.0
# 314                      4.3                      124.3
# 315                      2.4                       42.5
#
#      Ca Weight (%) (meq/L)  Mg Weight (%) (meq/L)  Na Weight (%) (meq/L)  \
# 311               1.431708               1.180004               4.632449
# ...
